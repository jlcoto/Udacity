# %%
import pandas as pd

filename = 'nyc_subway_weather.csv'
subway_df = pd.read_csv(filename)

def correlation(x, y):
    '''
    Fill in this function to compute the correlation between the two
    input variables. Each input is either a NumPy array or a Pandas
    Series.
    
    correlation = average of (x in standard units) times (y in standard units)
    
    Remember to pass the argument "ddof=0" to the Pandas std() function!
    '''
    x_norm = (x - x.mean())/x.std(ddof=0)
    y_norm = (y - y.mean())/y.std(ddof=0)
    return (x_norm*y_norm).mean()

entries = subway_df['ENTRIESn_hourly']
cum_entries = subway_df['ENTRIESn']
rain = subway_df['meanprecipi']
temp = subway_df['meantempi']

print correlation(entries, rain)
print correlation(entries, temp)
print correlation(rain, temp)

print correlation(entries, cum_entries)
# Out:
# 0.0356485157722
# -0.0266933483216
# -0.229034323408
# 0.585895470766

# %%
entries_and_exits = pd.DataFrame({
    'ENTRIESn': [3144312, 3144335, 3144353, 3144424, 3144594,
                 3144808, 3144895, 3144905, 3144941, 3145094],
    'EXITSn': [1088151, 1088159, 1088177, 1088231, 1088275,
               1088317, 1088328, 1088331, 1088420, 1088753]
})
def get_hourly_entries_and_exits(entries_and_exits):
    '''
    Fill in this function to take a DataFrame with cumulative entries
    and exits (entries in the first column, exits in the second) and
    return a DataFrame with hourly entries and exits (entries in the
    first column, exits in the second).
    '''
    return entries_and_exits.subtract(entries_and_exits.shift(), fill_value=0)

# %%
# Out:
#     ENTRIESn     EXITSn
# 0  3144312.0  1088151.0
# 1       23.0        8.0
# 2       18.0       18.0
# 3       71.0       54.0
# 4      170.0       44.0
# 5      214.0       42.0
# 6       87.0       11.0
# 7       10.0        3.0
# 8       36.0       89.0
# 9      153.0      333.0

# %%
grades_df = pd.DataFrame(
    data={'exam1': [43, 81, 78, 75, 89, 70, 91, 65, 98, 87],
          'exam2': [24, 63, 56, 56, 67, 51, 79, 46, 72, 60]},
    index=['Andre', 'Barry', 'Chris', 'Dan', 'Emilio', 
           'Fred', 'Greta', 'Humbert', 'Ivan', 'James']
)

# %%
def standardize_rows(df):
    '''
    Optional: Fill in this function to standardize each row of the given
    DataFrame. Again, try not to use apply().
    
    This one is more challenging than standardizing each column!
    '''
    return (df.subtract(df.mean(axis=1), axis=1)) / df.std(axis=1, ddof=0)

# %%
grades_df
# Out:
#          exam1  exam2
# Andre       43     24
# Barry       81     63
# Chris       78     56
# Dan         75     56
# Emilio      89     67
# Fred        70     51
# Greta       91     79
# Humbert     65     46
# Ivan        98     72
# James       87     60

# %%
grades_df.subtract(grades_df.mean(axis=1), axis=0) / grades_df.std(axis=1, ddof=0)
# Out:
#          Andre  Barry  Chris  Dan  Emilio  Fred  Greta  Humbert  Ivan  James  \
# Andre      NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Barry      NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Chris      NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Dan        NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Emilio     NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Fred       NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Greta      NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Humbert    NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# Ivan       NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
# James      NaN    NaN    NaN  NaN     NaN   NaN    NaN      NaN   NaN    NaN
#
#          exam1  exam2
# Andre      NaN    NaN
# Barry      NaN    NaN
# Chris      NaN    NaN
# Dan        NaN    NaN
# ...

# %%
grades_df.std(axis=1)
# Out:
# Andre      13.435029
# Barry      12.727922
# Chris      15.556349
# Dan        13.435029
# Emilio     15.556349
# Fred       13.435029
# Greta       8.485281
# Humbert    13.435029
# Ivan       18.384776
# James      19.091883
# dtype: float64

# %%
(grades_df.subtract(grades_df.mean(axis=1), axis=0)).divide(grades_df.std(axis=1), axis=0)
# Out:
#             exam1     exam2
# Andre    0.707107 -0.707107
# Barry    0.707107 -0.707107
# Chris    0.707107 -0.707107
# Dan      0.707107 -0.707107
# Emilio   0.707107 -0.707107
# Fred     0.707107 -0.707107
# Greta    0.707107 -0.707107
# Humbert  0.707107 -0.707107
# Ivan     0.707107 -0.707107
# James    0.707107 -0.707107

# %%
grades_df.std(axis=1)
# Out:
# Andre      13.435029
# Barry      12.727922
# Chris      15.556349
# Dan        13.435029
# Emilio     15.556349
# Fred       13.435029
# Greta       8.485281
# Humbert    13.435029
# Ivan       18.384776
# James      19.091883
# dtype: float64

# %%
grades_df.mean(axis=1)
# Out:
# Andre      33.5
# Barry      72.0
# Chris      67.0
# Dan        65.5
# Emilio     78.0
# Fred       60.5
# Greta      85.0
# Humbert    55.5
# Ivan       85.0
# James      73.5
# dtype: float64

# %%
grades_df
# Out:
#          exam1  exam2
# Andre       43     24
# Barry       81     63
# Chris       78     56
# Dan         75     56
# Emilio      89     67
# Fred        70     51
# Greta       91     79
# Humbert     65     46
# Ivan        98     72
# James       87     60

# %%
difference = grades_df.subtract(grades_df.mean(axis=1), axis=0)

# %%
difference.divide(grades_df.std(axis=1), axis=0)
# Out:
#             exam1     exam2
# Andre    0.707107 -0.707107
# Barry    0.707107 -0.707107
# Chris    0.707107 -0.707107
# Dan      0.707107 -0.707107
# Emilio   0.707107 -0.707107
# Fred     0.707107 -0.707107
# Greta    0.707107 -0.707107
# Humbert  0.707107 -0.707107
# Ivan     0.707107 -0.707107
# James    0.707107 -0.707107

# %%
difference
# Out:
#          exam1  exam2
# Andre      9.5   -9.5
# Barry      9.0   -9.0
# Chris     11.0  -11.0
# Dan        9.5   -9.5
# Emilio    11.0  -11.0
# Fred       9.5   -9.5
# Greta      6.0   -6.0
# Humbert    9.5   -9.5
# Ivan      13.0  -13.0
# James     13.5  -13.5

# %%
difference
